# %%
import sys, os, time
import numpy as np
import pickle
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib tk
import matplotlib.pyplot as plt
import networkx as nx
import tnt_util as util
from tnt_util import xdict, xset, collate, load, render_dict, get_object, save
from tnt_setup import init_gamestate, setup_phase
from tnt_cards import load_card_decks, draw_cards
from tnt_errors import TestManager
from collections import namedtuple

# %%
np.random.seed(10)
G = init_gamestate()
G.keys()
# Out:
# xdict_keys('tiles', 'nations', 'players', 'minors', 'action_cards', 'investment_cards', 'units')

# %%
render_dict(G)
# Out:
# <div id="dad3c7a6-defa-4e26-b114-d20c326680a0" style="height: 600px; width:100%;"></div>

# %%
#cards, shuffled = draw_cards(G.action_cards, 7)
#G.action_cards.discard_pile.extend(cards)
print(len(G.action_cards.discard_pile), len(G.action_cards.deck))
#cards
# Out:
# 0 55

# %%
manager = TestManager()
manager.empty()
# Out:
# True

# %%
m = manager.get()
m
# Out:
# Waiting for message...WARNING: Overwriting id=100
#  received
# {'nationality':'Britain', 'player':'West', 'tile':'Delhi', 'type':'Infantry'}

# %%
m._id
# Out:
# 100

# %%
manager.empty()
# Out:
# False

# %%
# msg = xdict({'test':'test'})
# manager.put(msg)
# msg

# %%
manager.run(setup_phase, G)
# Out:
# Sent message
# Sent message
# Sent message
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Sent message
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Sent message
# Waiting for message... received
# Waiting for message... received
# Sent message
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Waiting for message... received
# Sent message
# Waiting for message... received
# Sent message
# Waiting for message... received
# Waiting for message...Error in this phase!
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-6-78b3117b0fa4> in <module>()
# ----> 1 manager.run(setup_phase, G)
#
# /mnt/c/Users/anwan/OneDrive - UW/Khan/Other/tnt/tnt_errors.py in run(self, phase, state, checkpoint, **kwargs)
#      62                         except Exception as e:
#      63                                 print('Error in this phase!')
# ---> 64                                 raise e
#      65                         else:
#      66                                 break
#
# /mnt/c/Users/anwan/OneDrive - UW/Khan/Other/tnt/tnt_errors.py in run(self, phase, state, checkpoint, **kwargs)
#      56                 for _ in range(self.max_trials):
#      57                         try:
# ---> 58                                 phase(state, self, **kwargs)
#      59                         except GameStateError as e:
#      60                                 if checkpoint:
#
# /mnt/c/Users/anwan/OneDrive - UW/Khan/Other/tnt/tnt_setup.py in setup_phase(G, io, player_setup_path)
#     196
#     197                 try:
# --> 198                         msg = io.get()
#     199
#     200                         assert msg.player in incomplete, 'Player {} is already done'.format(msg.player)
#
# /mnt/c/Users/anwan/OneDrive - UW/Khan/Other/tnt/tnt_errors.py in get(self, wait)
#      45                 if not wait and self.inbox.empty():
#      46                         return None
# ---> 47                 msg = collate(eval(self.inbox.get()))
#      48                 print(' received')
#      49                 return msg
#
# <string> in get(self, *args, **kwds)
#
# ~/anaconda3/lib/python3.7/multiprocessing/managers.py in _callmethod(self, methodname, args, kwds)
#     794
#     795         conn.send((self._id, methodname, args, kwds))
# --> 796         kind, result = conn.recv()
#     797
#     798         if kind == '#RETURN':
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     405
#     406     def _recv_bytes(self, maxsize=None):
# --> 407         buf = self._recv(4)
#     408         size, = struct.unpack("!i", buf.getvalue())
#     409         if maxsize is not None and size > maxsize:
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in _recv(self, size, read)
#     381             if n == 0:
#     382                 if remaining == size:
# --> 383                     raise EOFError
#     384                 else:
#     385                     raise OSError("got end of file during message")
#
# EOFError:
