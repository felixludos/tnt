# %%
import sys, os, time
import numpy as np
import pickle
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib tk
import matplotlib.pyplot as plt
import networkx as nx
from tnt_util import xset, adict, idict, render_dict
from collections import OrderedDict
from tnt_setup import init_gamestate

# %%
G = init_gamestate()

# %%
render_dict(G)
# Out:
# <div id="bcc0143c-c5d4-4213-8247-082ac1ab95ff" style="height: 600px; width:100%;"></div>
