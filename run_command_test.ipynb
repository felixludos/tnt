# %%
import sys, os, time
import numpy as np
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
#%matplotlib tk
import matplotlib.pyplot as plt
from tnt_util import *
from util import adict, idict, xset, collate, load, render_dict, save, Logger, seq_iterate
from tnt_setup import init_gamestate, setup_phase
from tnt_cards import load_card_decks, draw_cards
from collections import namedtuple
import random
from itertools import chain, product
from tnt_units import load_unit_rules
import tnt_setup as setup

from flask_app import *

# %%
ping()
# Out:
# 'Backend active: use "init" to init game'

# %%
out = format_msg_to_python(init_game(debug=False, player='Axis'))
# Out:
# Beginning phase: Setup
# Game saved

# %%
path = 'saves/gov_complete.json'
path = 'saves/cmd_test.json'
load(path)
# Out:
# Game loaded

# %%
G = get_G()
render_dict(G)
# Out:
# <div id="77a8b2cf-ab85-4c1b-b670-ef37da7e560f" style="height: 600px; width:100%;"></div>

# %%
action = ('pass',)
player = 'Axis'

# %%
out = format_msg_to_python(get_status(player))
if 'log' in out:
    print('{} LOG'.format(player))
    print(out.log)
if 'error' in out:
    print(out.error)
print('created: {}'.format(', '.join(map(str, out.created))))
print('updated: {}'.format(', '.join(map(str, out.updated))))
print('removed: {}'.format(', '.join(map(str, out.removed))))
# Out:
# Axis LOG
# Game loaded
# West plays a card
# USSR has played a bluff (investment card)
# Axis has played an emergency command: Y 4
# West has played a bluff (investment card)
# Play order is: Axis
#
# created:
# updated: invest_55, invest_22, action_39
# removed:

# %%
if 'actions' in out:
    actions = list(util.decode_actions(out.actions))
    print('ACTIONS: {}'.format(len(actions)))
    for i, a in enumerate(actions):
        print(i, a)
if 'waiting_for' in out:
    print('WAITING: {}'.format(out.waiting_for))
#render_dict(out)
# Out:
# ACTIONS: 136
# 0 (117, 'Nordkapp_Sea')
# 1 (119, 'Ruhr')
# 2 (119, 'English_Channel')
# 3 (128, 'Berlin')
# 4 (121, 'Adriatic_Sea')
# 5 (129, 'Ruhr')
# 6 (124, 'Sardinia')
# 7 (119, 'Berlin')
# 8 (134, 'Milan')
# 9 (116, 'Berlin')
# 10 (129, 'Berlin')
# 11 (118, 'Sicily')
# 12 (123, 'Taranto')
# 13 (132, 'Western_Mediterranean')
# 14 (117, 'Gulf_of_Bothnia')
# 15 (117, 'Norwegian_Sea')
# 16 (118, 'Taranto')
# 17 (121, 'Cyrenaica')
# 18 (117, 'Berlin')
# 19 (162, 'Rome')
# 20 (134, 'Taranto')
# 21 (116, 'Konigsberg')
# 22 (117, 'Greenland_Sea')
# 23 (129, 'Gulf_of_Bothnia')
# 24 (120, 'Berlin')
# 25 (162, 'Western_Mediterranean')
# 26 (119, 'Bay_of_Biscay')
# 27 (121, 'Tripoli')
# 28 (118, 'Eastern_Mediterranean')
# 29 (118, 'Tripoli')
# 30 (134, 'Western_Mediterranean')
# 31 (126, 'Gulf_of_Bothnia')
# 32 (119, 'Baltic_Sea')
# 33 (119, 'Irish_Sea')
# 34 (162, 'Milan')
# 35 (118, 'Crete')
# 36 (117, 'Bay_of_Biscay')
# 37 (116, 'Baltic_Sea')
# 38 (135, 'Berlin')
# 39 (121, 'Taranto')
# 40 (121, 'Sicily')
# 41 (122, 'Baltic_Sea')
# 42 (162, 'Taranto')
# 43 (132, 'Taranto')
# 44 (119, 'Munich')
# 45 (123, 'Western_Mediterranean')
# 46 (121, 'Crete')
# 47 (133, 'Berlin')
# 48 (123, 'Rome')
# 49 (128, 'Munich')
# 50 (130, 'Berlin')
# 51 (123, 'Tyrrhenian_Sea')
# 52 (133, 'Ruhr')
# 53 (119, 'North_Sea')
# 54 (162, 'Sardinia')
# 55 (124, 'Sicily')
# 56 (126, 'Konigsberg')
# 57 (117, 'English_Channel')
# 58 (117, 'Ruhr')
# 59 (121, 'Aegean_Sea')
# 60 (132, 'Sicily')
# 61 (132, 'Milan')
# 62 (135, 'Baltic_Sea')
# 63 (120, 'Gulf_of_Bothnia')
# 64 (135, 'Gulf_of_Bothnia')
# 65 (123, 'Venice')
# 66 (129, 'Baltic_Sea')
# 67 (130, 'Munich')
# 68 (119, 'Konigsberg')
# 69 (115, 'Munich')
# 70 (122, 'Berlin')
# 71 (118, 'Aegean_Sea')
# 72 (121, 'Eastern_Mediterranean')
# 73 (124, 'Rome')
# 74 (124, 'Tyrrhenian_Sea')
# 75 (124, 'Western_Mediterranean')
# 76 (122, 'English_Channel')
# 77 (162, 'Venice')
# 78 (116, 'Gulf_of_Bothnia')
# 79 (122, 'Ruhr')
# 80 (117, 'Irish_Sea')
# 81 (117, 'Baltic_Sea')
# 82 (130, 'Ruhr')
# 83 (132, 'Rome')
# 84 (117, 'North_Sea')
# 85 (122, 'Konigsberg')
# 86 (118, 'Adriatic_Sea')
# 87 (117, 'Konigsberg')
# 88 (122, 'Gulf_of_Bothnia')
# 89 (124, 'Milan')
# 90 ('pass',)
# 91 (134, 'Sardinia')
# 92 (126, 'Baltic_Sea')
# 93 (120, 'Konigsberg')
# 94 (119, 'Gulf_of_Bothnia')
# 95 (115, 'Konigsberg')
# 96 (119, 'Norwegian_Sea')
# 97 (132, 'Venice')
# 98 (123, 'Sicily')
# 99 (122, 'North_Sea')
# 100 (118, 'Venice')
# 101 (120, 'Baltic_Sea')
# 102 (135, 'Konigsberg')
# 103 (134, 'Tyrrhenian_Sea')
# 104 (134, 'Venice')
# 105 (134, 'Rome')
# 106 (115, 'Berlin')
# 107 (132, 'Tyrrhenian_Sea')
# 108 (133, 'Baltic_Sea')
# 109 (118, 'Cyrenaica')
# 110 (129, 'Munich')
# 111 (162, 'Sicily')
# 112 (130, 'Baltic_Sea')
# 113 (162, 'Adriatic_Sea')
# 114 (123, 'Sardinia')
# 115 (133, 'Konigsberg')
# 116 (115, 'Ruhr')
# 117 (119, 'Greenland_Sea')
# 118 (132, 'Sardinia')
# 119 (118, 'Central_Mediterranean')
# 120 (122, 'Norwegian_Sea')
# 121 (134, 'Sicily')
# 122 (116, 'Ruhr')
# 123 (133, 'Gulf_of_Bothnia')
# 124 (126, 'Berlin')
# 125 (121, 'Central_Mediterranean')
# 126 (119, 'Nordkapp_Sea')
# 127 (126, 'Ruhr')
# 128 (162, 'Tyrrhenian_Sea')
# 129 (120, 'Ruhr')
# 130 (115, 'Gulf_of_Bothnia')
# 131 (115, 'Baltic_Sea')
# 132 (123, 'Milan')
# 133 (128, 'Ruhr')
# 134 (135, 'Ruhr')
# 135 (129, 'Konigsberg')

# %%
action = actions[0]

# %%
out = format_msg_to_python(take_action(player, action))
if 'waiting_for' in out:
    player = out.waiting_for.pop()
    print('SWITCHING to {}'.format(player))
if 'error' in out:
    print(out.error)
# Out:
# SWITCHING to Axis

# %%
G.tiles.Algiers
# Out:
# {'type':'Coast', 'alligence':'French_North_Africa', 'res':0, 'pop':1, 'muster':2, 'borders':{'Gibraltar':'Strait', 'Morocco':'Mountains', 'Tunisia':'Mountains', 'Western_Mediterranean':'Coast'}, 'name':'Algiers', 'units':{148}, 'obj_type':'tile', 'visible':{'USSR', 'West', 'Axis'}}

# %%
out.created['604']
# Out:
# {'value':1, 'nation':'Yugoslavia', 'faction':'Axis', 'obj_type':'influence', 'visible':{'USSR', 'Axis', 'West'}}

# %%
path = save('cmd_test.json')
path
# Out:
# Game saved
# 'saves/cmd_test.json'

# %%
G.objects.table[116]
# Out:
# { 'nationality':'Germany', 'tile':'Konigsberg', 'type':'Tank', 'obj_type':'unit', 'cv':1, 'visible':{'Axis'}}

# %%
# take_action('USSR', None)

# %%
G = get_G()

# %%
try:
    for player in G.game.turn_order:
        fixed[player] = [('investment_card',)]*6# + [('action_card',)]
    players = G.game.turn_order
except KeyError:
    players = ['Axis', 'USSR', 'West']
print(players)
# Out:
# ['Axis', 'USSR', 'West']

# %%
for player in players:
    while True:
        out = format_msg_to_python(get_status(player))

        if 'error' in out:
            print(out.error)
            break

        if 'log' in out:
            print(out.log)

        if 'waiting_for' in out:
            print('-- {} is waiting for {}'.format(player, out.waiting_for))
            break

        if player in fixed and len(fixed[player]):
            action = fixed[player].pop()
            print('-- from {} chose {}'.format('fixed', action))
        else:
            actions = list(util.decode_actions(out.actions))
            action = random.choice(actions)
            print('-- from {} chose {}'.format(len(actions), action))
        
        out = format_msg_to_python(take_action(player, action))
# Out:
# Beginning phase: Setup
# Game saved
#
# -- from 46 chose ('Germany', 'Konigsberg', 'Carrier')
#
# -- from 46 chose ('Germany', 'Ruhr', 'Tank')
#
# -- from 46 chose ('Germany', 'Ruhr', 'Fleet')
#
# -- from 46 chose ('Italy', 'Milan', 'Fleet')
#
# -- from 46 chose ('Italy', 'Rome', 'Submarine')
#
# -- from 46 chose ('Italy', 'Rome', 'Submarine')
#
# -- from 43 chose ('Germany', 'Ruhr', 'Submarine')
#
# -- from 43 chose ('Germany', 'Konigsberg', 'Carrier')
#
# -- from 34 chose ('Germany', 'Ruhr', 'Tank')
#
# -- from 28 chose ('Italy', 'Rome', 'AirForce')
#
# -- from 28 chose ('Germany', 'Munich', 'Infantry')
#
# -- from 28 chose ('Germany', 'Munich', 'Fortress')
#
# -- from 24 chose ('Italy', 'Rome', 'Carrier')
#
# -- from 16 chose ('Italy', 'Milan', 'AirForce')
#
# -- from 11 chose ('Italy', 'Tripoli', 'Fleet')
#
# -- from 11 chose ('Germany', 'Berlin', 'Submarine')
#
# -- from 11 chose ('Italy', 'Tripoli', 'Tank')
#
# -- from 6 chose ('Germany', 'Berlin', 'Fleet')
#
# -- from 6 chose ('Germany', 'Berlin', 'Submarine')
#
# -- from 6 chose ('Germany', 'Berlin', 'Submarine')
#
# -- from 6 chose ('Germany', 'Berlin', 'Submarine')
#
# -- from 6 chose ('Germany', 'Berlin', 'AirForce')
# Axis draws 14 action cards (now holding 14 cards)
#
# -- Axis is waiting for {'USSR', 'West'}
# Beginning phase: Setup
# Game saved
# Axis draws 14 action cards (now holding 14 cards)
#
# -- from 44 chose ('USSR', 'Kharkov', 'Fleet')
#
# -- from 37 chose ('USSR', 'Leningrad', 'Carrier')
#
# -- from 37 chose ('USSR', 'Odessa', 'Fleet')
#
# -- from 30 chose ('USSR', 'Leningrad', 'Tank')
#
# -- from 23 chose ('USSR', 'Urals', 'Fortress')
#
# -- from 19 chose ('USSR', 'Baku', 'Fleet')
#
# -- from 19 chose ('USSR', 'Baku', 'Fortress')
#
# -- from 12 chose ('USSR', 'Moscow', 'Fortress')
#
# -- from 11 chose ('USSR', 'Stalingrad', 'AirForce')
#
# -- from 7 chose ('USSR', 'Kiev', 'AirForce')
#
# -- from 3 chose ('USSR', 'Moscow', 'AirForce')
#
# -- from 3 chose ('USSR', 'Moscow', 'Infantry')
# USSR draws 6 action cards (now holding 6 cards)
#
# -- USSR is waiting for {'West'}
# Beginning phase: Setup
# Game saved
# Axis draws 14 action cards (now holding 14 cards)
# USSR draws 6 action cards (now holding 6 cards)
#
# -- from 56 chose ('France', 'Paris', 'Fleet')
#
# -- from 56 chose ('Britain', 'Glasgow', 'Carrier')
#
# -- from 49 chose ('France', 'Algiers', 'Fleet')
#
# -- from 42 chose ('France', 'Marseille', 'Carrier')
#
# -- from 34 chose ('Britain', 'London', 'Submarine')
#
# -- from 34 chose ('Britain', 'Suez', 'Submarine')
#
# -- from 27 chose ('France', 'Paris', 'Fleet')
#
# -- from 21 chose ('Britain', 'London', 'Carrier')
#
# -- from 18 chose ('Britain', 'London', 'Fortress')
#
# -- from 12 chose ('Britain', 'Bombay', 'AirForce')
#
# -- from 6 chose ('Britain', 'Delhi', 'Submarine')
#
# -- from 5 chose ('Britain', 'Delhi', 'Fortress')
# West draws 8 action cards (now holding 8 cards)
#
# -- West is waiting for {}

# %%
# Out:
# <div id="b1f59bed-48ff-43eb-bacc-2da7c417cbb6" style="height: 600px; width:100%;"></div>

# %%
# path = save('prod_complete.json')
# path

# %%
# sorted(5+g for g in range(50))

# %%
player = 'West'
draw_cards(G, 'investment', player, 20)
# Out:
# West draws 20 investment cards (now holding 35 cards)

# %%
cards = tdict({ID:G.objects.table[ID] for ID in G.players[player].hand})
render_dict(cards)
# Out:
# <div id="42a00ef4-0122-4d9d-a12d-c3d275360355" style="height: 600px; width:100%;"></div>

# %%
player = 'West'

# %%
player = 'USSR'

# %%
player = 'Axis'

# %%
player
# Out:
# 'Axis'

# %%
out = format_msg_to_python(get_status(player))

# %%
if 'log' in out:
    print(out.log)
if 'error' in out:
    print(out.error)
# Out:
# Axis spends 1 production on building a new cadre in Venice (0 production remaining)
# Axis draws 1 action cards (now holding 15 cards)
# Axis draws 6 investment cards (now holding 21 cards)
# Axis is done with production

# %%
render_dict(out)
# Out:
# <div id="b9fc849c-c5e8-458e-9e38-e963213dcf5d" style="height: 600px; width:100%;"></div>

# %%
actions = list(util.decode_actions(out.actions))
actions

# %%
render_dict(adict({ID:G.objects.table[ID] for ID in G.players[player].hand}))

# %%
# action = random.choice(actions)
# action
action = ('factory_upgrade',)

# %%
player = 'West'

# %%
player = 'USSR'

# %%
player = 'Axis'

# %%
player
# Out:
# 'Axis'

# %%
action = ('cancel',)
action = ('Britain', 'Glasgow', 'Submarine')
action = ('pass',)

# %%
out = format_msg_to_python(take_action(player, action))
# Out:
# 27
# 0 0
# {}
# dict_keys([])
# adict()

# %%
if 'log' in out:
    print(out.log)
if 'error' in out:
    print(out.error)
# Out:
# Game loaded
# USSR draws 20 investment cards (now holding 32 cards)
# Beginning phase: Government
# Game saved

# %%
render_dict(out)
# Out:
# <div id="b751ee81-bf87-4e66-b7fa-524b2be5b163" style="height: 600px; width:100%;"></div>
